kB/s eta 0:00:06
#    -------------------------------- ------- 19.4/24.0 MB 855.8 kB/s eta 0:00:06
#    -------------------------------- ------- 19.4/24.0 MB 855.8 kB/s eta 0:00:06
#    -------------------------------- ------- 19.7/24.0 MB 853.2 kB/s eta 0:00:06
#    -------------------------------- ------- 19.7/24.0 MB 853.2 kB/s eta 0:00:06
#    --------------------------------- ------ 19.9/24.0 MB 853.7 kB/s eta 0:00:05
#    --------------------------------- ------ 19.9/24.0 MB 853.7 kB/s eta 0:00:05
#    --------------------------------- ------ 20.2/24.0 MB 846.7 kB/s eta 0:00:05
#    --------------------------------- ------ 20.2/24.0 MB 846.7 kB/s eta 0:00:05
#    ---------------------------------- ----- 20.4/24.0 MB 842.7 kB/s eta 0:00:05
#    ---------------------------------- ----- 20.4/24.0 MB 842.7 kB/s eta 0:00:05
#    ---------------------------------- ----- 20.7/24.0 MB 836.7 kB/s eta 0:00:04
#    ---------------------------------- ----- 20.7/24.0 MB 836.7 kB/s eta 0:00:04
#    ---------------------------------- ----- 21.0/24.0 MB 835.2 kB/s eta 0:00:04
#    ---------------------------------- ----- 21.0/24.0 MB 835.2 kB/s eta 0:00:04
#    ----------------------------------- ---- 21.2/24.0 MB 834.7 kB/s eta 0:00:04
#    ----------------------------------- ---- 21.5/24.0 MB 832.7 kB/s eta 0:00:04
#    ----------------------------------- ---- 21.5/24.0 MB 832.7 kB/s eta 0:00:04
#    ----------------------------------- ---- 21.5/24.0 MB 832.7 kB/s eta 0:00:04
#    ------------------------------------ --- 21.8/24.0 MB 824.8 kB/s eta 0:00:03
#    ------------------------------------ --- 21.8/24.0 MB 824.8 kB/s eta 0:00:03
#    ------------------------------------ --- 21.8/24.0 MB 824.8 kB/s eta 0:00:03
#    ------------------------------------ --- 22.0/24.0 MB 816.2 kB/s eta 0:00:03
#    ------------------------------------- -- 22.3/24.0 MB 817.0 kB/s eta 0:00:03
#    ------------------------------------- -- 22.5/24.0 MB 818.6 kB/s eta 0:00:02
#    ------------------------------------- -- 22.5/24.0 MB 818.6 kB/s eta 0:00:02
#    ------------------------------------- -- 22.8/24.0 MB 815.6 kB/s eta 0:00:02
#    ------------------------------------- -- 22.8/24.0 MB 815.6 kB/s eta 0:00:02
#    -------------------------------------- - 23.1/24.0 MB 815.0 kB/s eta 0:00:02
#    -------------------------------------- - 23.3/24.0 MB 816.6 kB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.0 MB 816.6 kB/s eta 0:00:01
#    ---------------------------------------  23.6/24.0 MB 816.8 kB/s eta 0:00:01
#    ---------------------------------------  23.6/24.0 MB 816.8 kB/s eta 0:00:01
#    ---------------------------------------  23.9/24.0 MB 814.0 kB/s eta 0:00:01
#    ---------------------------------------- 24.0/24.0 MB 810.6 kB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install operator
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement operator (from versions: none)
# ERROR: No matching distribution found for operator

# %%
df_movies = pd.read_csv('movies.csv')
df_movies.head()
# Out:
#    rank                     title                                    genre  \
# 0     0             The Godfather                   [u' Crime', u' Drama']
# 1     1  The Shawshank Redemption                   [u' Crime', u' Drama']
# 2     2          Schindler's List  [u' Biography', u' Drama', u' History']
# 3     3               Raging Bull    [u' Biography', u' Drama', u' Sport']
# 4     4                Casablanca        [u' Drama', u' Romance', u' War']
#
#                                            wiki_plot  \
# 0  On the day of his only daughter's wedding, Vit...
# 1  In 1947, banker Andy Dufresne is convicted of ...
# 2  In 1939, the Germans move Polish Jews into the...
# 3  In a brief scene in 1964, an aging, overweight...
# 4  It is early December 1941. American expatriate...
#
#                                            imdb_plot
# 0  In late summer 1945, guests are gathered for t...
# 1  In 1947, Andy Dufresne (Tim Robbins), a banker...
# 2  The relocation of Polish Jews from surrounding...
# 3  The film opens in 1964, where an older and fat...
# 4  In the early years of World War II, December 1...

# %%
from spacy.lang.en.stop_words import STOP_WORDS

spacy_nlp = spacy.load('en_core_web_sm')

#create list of punctuations and stopwords
punctuations = string.punctuation
stop_words = spacy.lang.en.stop_words.STOP_WORDS

#function for data cleaning and processing
#This can be further enhanced by adding / removing reg-exps as desired.

def spacy_tokenizer(sentence):
 
    #remove distracting single quotes
    sentence = re.sub('\'','',sentence)

    #remove digits adnd words containing digits
    sentence = re.sub(r'\w*\d\w*', '', sentence)


    #replace extra spaces with single space
    sentence = re.sub(' +',' ',sentence)

    #remove unwanted lines starting from special charcters
    sentence = re.sub(r'\n: \'\'.*','',sentence)
    sentence = re.sub(r'\n!.*','',sentence)
    sentence = re.sub(r'^:\'\'.*','',sentence)
    
    #remove non-breaking new line characters
    sentence = re.sub(r'\n',' ',sentence)
    
    #remove punctunations
    sentence = re.sub(r'[^\w\s]',' ',sentence)
    
    #creating token object
    tokens = spacy_nlp(sentence)
    
    #lower, strip and lemmatize
    tokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in tokens]
    
    #remove stopwords, and exclude words less than 2 characters
    tokens = [word for word in tokens if word not in stop_words and word not in punctuations and len(word) > 2]
    
    #return tokens
    return tokens

# %%
print ('Cleaning and Tokenizing...')
# %time df_movies['wiki_plot_tokenized'] = df_movies['wiki_plot'].map(lambda x: spacy_tokenizer(x))

df_movies.head()
# Out:
# Cleaning and Tokenizing...
# CPU times: total: 1min 10s
# Wall time: 1min 12s
#    rank                     title                                    genre  \
# 0     0             The Godfather                   [u' Crime', u' Drama']
# 1     1  The Shawshank Redemption                   [u' Crime', u' Drama']
# 2     2          Schindler's List  [u' Biography', u' Drama', u' History']
# 3     3               Raging Bull    [u' Biography', u' Drama', u' Sport']
# 4     4                Casablanca        [u' Drama', u' Romance', u' War']
#
#                                            wiki_plot  \
# 0  On the day of his only daughter's wedding, Vit...
# 1  In 1947, banker Andy Dufresne is convicted of ...
# 2  In 1939, the Germans move Polish Jews into the...
# 3  In a brief scene in 1964, an aging, overweight...
# 4  It is early December 1941. American expatriate...
#
#                                            imdb_plot  \
# 0  In late summer 1945, guests are gathered for t...
# 1  In 1947, Andy Dufresne (Tim Robbins), a banker...
# 2  The relocation of Polish Jews from surrounding...
# 3  The film opens in 1964, where an older and fat...
# 4  In the early years of World War II, December 1...
#
#                                  wiki_plot_tokenized
# 0  [day, daughter, wed, vito, corleone, hear, req...
# 1  [banker, andy, dufresne, convict, murder, wife...
# 2  [germans, polish, jews, kraków, ghetto, world,...
# 3  [brief, scene, age, overweight, italian, ameri...
# 4  [early, december, american, expatriate, rick, ...

# %%
movie_plot = df_movies['wiki_plot_tokenized']
movie_plot[0:5]
# Out:
# 0    [day, daughter, wed, vito, corleone, hear, req...
# 1    [banker, andy, dufresne, convict, murder, wife...
# 2    [germans, polish, jews, kraków, ghetto, world,...
# 3    [brief, scene, age, overweight, italian, ameri...
# 4    [early, december, american, expatriate, rick, ...
# Name: wiki_plot_tokenized, dtype: object

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

series = pd.Series(np.concatenate(movie_plot)).value_counts()[:100]
wordcloud = WordCloud(background_color='white').generate_from_frequencies(series)

plt.figure(figsize=(15,15), facecolor = None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from gensim import corpora

#creating term dictionary
# %time dictionary = corpora.Dictionary(movie_plot)

#filter out terms which occurs in less than 4 documents and more than 20% of the documents.
#NOTE: Since we have smaller dataset, we will keep this commented for now.

#dictionary.filter_extremes(no_below=4, no_above=0.2)

#list of few which which can be further removed
stoplist = set('hello and if this can would should could tell ask stop come go')
stop_ids = [dictionary.token2id[stopword] for stopword in stoplist if stopword in dictionary.token2id]
dictionary.filter_tokens(stop_ids)
# Out:
# CPU times: total: 125 ms
# Wall time: 113 ms

# %%
#print top 50 items from the dictionary with their unique token-id
dict_tokens = [[[dictionary[key], dictionary.token2id[dictionary[key]]] for key, value in dictionary.items() if key <= 50]]
print (dict_tokens)
# Out:
# [[['abrasive', 0], ['abroad', 1], ['abuse', 2], ['accept', 3], ['accuse', 4], ['act', 5], ['adams', 6], ['add', 7], ['address', 8], ['agree', 9], ['ambush', 10], ['angeles', 11], ['answer', 12], ['anthony', 13], ['apollonia', 14], ['arrange', 15], ['ask', 16], ['assassin', 17], ['assassination', 18], ['associate', 19], ['attack', 20], ['attempt', 21], ['authority', 22], ['aware', 23], ['baron', 24], ['barzini', 25], ['battle', 26], ['bed', 27], ['betrayal', 28], ['bodyguard', 29], ['bomb', 30], ['booth', 31], ['brasi', 32], ['brasis', 33], ['break', 34], ['bronx', 35], ['brother', 36], ['business', 37], ['buy', 38], ['capos', 39], ['captain', 40], ['car', 41], ['career', 42], ['carlo', 43], ['casino', 44], ['christening', 45], ['christmas', 46], ['clampdown', 47], ['clemenza', 48], ['collapse', 49], ['come', 50]]]

# %%
corpus = [dictionary.doc2bow(desc) for desc in movie_plot]

word_frequencies = [[(dictionary[id], frequency) for id, frequency in line] for line in corpus[0:3]]

print(word_frequencies)
# Out:
# [[('abrasive', 2), ('abroad', 2), ('abuse', 4), ('accept', 6), ('accuse', 2), ('act', 2), ('adams', 3), ('add', 2), ('address', 2), ('agree', 2), ('ambush', 2), ('angeles', 2), ('answer', 2), ('anthony', 3), ('apollonia', 2), ('arrange', 2), ('ask', 2), ('assassin', 4), ('assassination', 4), ('associate', 2), ('attack', 4), ('attempt', 4), ('authority', 2), ('aware', 2), ('baron', 2), ('barzini', 7), ('battle', 2), ('bed', 2), ('betrayal', 2), ('bodyguard', 2), ('bomb', 2), ('booth', 2), ('brasi', 3), ('brasis', 2), ('break', 2), ('bronx', 2), ('brother', 6), ('business', 6), ('buy', 2), ('capos', 3), ('captain', 2), ('car', 2), ('career', 2), ('carlo', 7), ('casino', 2), ('christening', 4), ('christmas', 2), ('clampdown', 2), ('clemenza', 3), ('collapse', 2), ('come', 4), ('command', 2), ('confess', 2), ('confront', 2), ('connection', 2), ('connie', 4), ('connies', 2), ('consigliere', 5), ('contact', 2), ('corleone', 10), ('corleones', 4), ('corps', 3), ('coveted', 2), ('crime', 2), ('daughter', 2), ('day', 4), ('deal', 2), ('dealer', 2), ('death', 4), ('decide', 2), ('deny', 2), ('deride', 2), ('despite', 2), ('devastate', 2), ('die', 2), ('disapprove', 2), ('dispatch', 2), ('dispute', 2), ('dominant', 2), ('don', 11), ('drug', 6), ('eld', 2), ('emerge', 2), ('emilio', 3), ('end', 6), ('enforcer', 2), ('erupt', 2), ('euphoria', 2), ('fade', 2), ('fall', 2), ('families', 5), ('family', 12), ('familys', 2), ('father', 8), ('fear', 2), ('feud', 2), ('fire', 2), ('fish', 4), ('fontane', 3), ('forgo', 2), ('fredo', 5), ('funeral', 2), ('garden', 2), ('garrote', 3), ('girlfriend', 2), ('godfather', 4), ('godson', 2), ('greene', 7), ('greenes', 4), ('guarantee', 2), ('gun', 2), ('hagen', 7), ('handgun', 2), ('happen', 4), ('head', 6), ('hear', 2), ('help', 2), ('heroin', 2), ('highway', 2), ('hit', 2), ('home', 4), ('hospital', 4), ('husband', 2), ('imparting', 2), ('influence', 2), ('injury', 2), ('insist', 2), ('insult', 2), ('intend', 2), ('introduce', 2), ('investment', 2), ('involvement', 4), ('jack', 3), ('jaw', 2), ('johnny', 3), ('kay', 11), ('kidnap', 2), ('kill', 10), ('land', 2), ('las', 7), ('law', 2), ('lead', 2), ('legitimate', 2), ('life', 2), ('los', 2), ('luca', 3), ('man', 4), ('marine', 3), ('marriage', 2), ('marry', 2), ('mccluskey', 4), ('meet', 2), ('meeting', 4), ('michael', 31), ('michaels', 6), ('moe', 5), ('morning', 2), ('movie', 2), ('murder', 8), ('new', 6), ('offer', 2), ('old', 2), ('open', 2), ('opposition', 2), ('order', 4), ('peter', 3), ('plan', 2), ('plant', 2), ('play', 2), ('plead', 2), ('police', 2), ('political', 2), ('popular', 2), ('power', 2), ('pressure', 2), ('pretext', 2), ('prized', 2), ('proceed', 2), ('promise', 4), ('protection', 2), ('question', 4), ('realise', 2), ('receive', 4), ('reception', 2), ('refuge', 2), ('rein', 2), ('relinquish', 2), ('relocate', 2), ('request', 2), ('restaurant', 2), ('retaliate', 2), ('retrieve', 2), ('return', 2), ('revenge', 2), ('riddle', 2), ('rival', 4), ('role', 6), ('sadden', 2), ('safety', 4), ('salvatore', 3), ('second', 2), ('secure', 2), ('send', 2), ('set', 4), ('settle', 2), ('sever', 2), ('shatter', 2), ('shelter', 2), ('shortly', 2), ('sicily', 2), ('signal', 2), ('singer', 2), ('sister', 2), ('sleep', 2), ('sollozzo', 7), ('sollozzos', 4), ('son', 12), ('sonny', 11), ('sonnys', 4), ('speed', 2), ('sprawl', 2), ('spy', 2), ('stake', 2), ('stallion', 3), ('stand', 2), ('street', 2), ('studio', 2), ('submachine', 2), ('survive', 2), ('sway', 2), ('tattaglias', 6), ('tell', 2), ('tessio', 5), ('threaten', 2), ('thwart', 2), ('time', 2), ('toll', 2), ('tom', 7), ('trade', 2), ('travel', 2), ('treachery', 2), ('turk', 3), ('uniform', 2), ('unmove', 2), ('vegas', 7), ('vest', 2), ('virgil', 3), ('vitelli', 2), ('vito', 19), ('vitos', 4), ('wake', 2), ('warfare', 2), ('warily', 2), ('warn', 2), ('wartime', 2), ('watch', 2), ('weak', 2), ('wed', 2), ('wire', 2), ('withdraw', 2), ('woltz', 5), ('wrap', 2), ('year', 4), ('york', 4), ('young', 2)], ...

# %%
# %time movie_tfidf_model = gensim.models.TfidfModel(corpus, id2word=dictionary)
# %time movie_lsi_model = gensim.models.LsiModel(movie_tfidf_model[corpus], id2word=dictionary, num_topics=300)
# Out:
# CPU times: total: 62.5 ms
# Wall time: 54 ms
# CPU times: total: 18.6 s
# Wall time: 4.01 s

# %%
# %time gensim.corpora.MmCorpus.serialize('movie_tfidf_model_mm', movie_tfidf_model[corpus])
# %time gensim.corpora.MmCorpus.serialize('movie_lsi_model_mm',movie_lsi_model[movie_tfidf_model[corpus]])
# Out:
# CPU times: total: 203 ms
# Wall time: 209 ms
# CPU times: total: 156 ms
# Wall time: 170 ms

# %%
#Load the indexed corpus
movie_tfidf_corpus = gensim.corpora.MmCorpus('movie_tfidf_model_mm')
movie_lsi_corpus = gensim.corpora.MmCorpus('movie_lsi_model_mm')

print(movie_tfidf_corpus)
print(movie_lsi_corpus)
# Out:
# MmCorpus(100 documents, 8407 features, 25990 non-zero entries)
# MmCorpus(100 documents, 100 features, 10000 non-zero entries)

# %%
from gensim.similarities import MatrixSimilarity

# %time movie_index = MatrixSimilarity(movie_lsi_corpus, num_features = movie_lsi_corpus.num_terms)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 39.1 ms

# %%
from operator import itemgetter

def search_similar_movies(search_term):

    query_bow = dictionary.doc2bow(spacy_tokenizer(search_term))
    query_tfidf = movie_tfidf_model[query_bow]
    query_lsi = movie_lsi_model[query_tfidf]

    movie_index.num_best = 5

    movies_list = movie_index[query_lsi]

    movies_list.sort(key=itemgetter(1), reverse=True)
    movie_names = []

    for j, movie in enumerate(movies_list):

        movie_names.append (
            {
                'Relevance': round((movie[1] * 100),2),
                'Movie Title': df_movies['title'][movie[0]],
                'Movie Plot': df_movies['wiki_plot'][movie[0]]
            }

        )
        if j == (movie_index.num_best-1):
            break

    return pd.DataFrame(movie_names, columns=['Relevance','Movie Title','Movie Plot'])

# %%
# search for movie tiles that are related to below search parameters
search_similar_movies('crime and drugs ')
# Out:
#    Relevance            Movie Title  \
# 0      81.54             Goodfellas
# 1      34.49  The French Connection
# 2      32.18          The Godfather
# 3      29.00     A Clockwork Orange
# 4      13.23      On the Waterfront
#
#                                           Movie Plot
# 0  Henry Hill (Liotta) admits, "As far back as I ...
# 1  In Marseille, an undercover detective is follo...
# 2  On the day of his only daughter's wedding, Vit...
# 3  In futuristic London, Alex DeLarge is the lead...
# 4  Mob-connected union boss Johnny Friendly (Lee ...

# %%
# search for movie tiles that are related to below search parameters
search_similar_movies('violence protest march')
# Out:
#    Relevance                     Movie Title  \
# 0      74.03                          Gandhi
# 1      52.20              A Clockwork Orange
# 2      27.05                         Amadeus
# 3      24.65  All Quiet on the Western Front
# 4      18.37     The Best Years of Our Lives
#
#                                           Movie Plot
# 0  The screenplay of Gandhi is available as a pub...
# 1  In futuristic London, Alex DeLarge is the lead...
# 2  The story begins in 1823 as the elderly Antoni...
# 3  \n\n\n\n\nThis section's plot summary may be t...
# 4  After World War II, Fred Derry (Dana Andrews),...

# %%
# search for movie tiles that are related to below search parameters
search_similar_movies('love affair hate')
# Out:
#    Relevance            Movie Title  \
# 0      45.56    Terms of Endearment
# 1      44.17           The Graduate
# 2      30.46  From Here to Eternity
# 3      29.43          Out of Africa
# 4      28.12      Wuthering Heights
#
#                                           Movie Plot
# 0  Aurora Greenway (Shirley MacLaine) and her dau...
# 1  Benjamin Braddock, going on from twenty to twe...
# 2  In 1941, bugler and career soldier Private Rob...
# 3  The story begins in 1913 in Denmark, when Kare...
# 4  A traveller named Lockwood (Miles Mander) is c...

# %%
#practice
search_similar_movies('crime')
# Out:
#    Relevance         Movie Title  \
# 0      75.60          Goodfellas
# 1      41.25   On the Waterfront
# 2      26.94      The Green Mile
# 3      25.27  A Clockwork Orange
# 4      20.62       The Godfather
#
#                                           Movie Plot
# 0  Henry Hill (Liotta) admits, "As far back as I ...
# 1  Mob-connected union boss Johnny Friendly (Lee ...
# 2  In a Louisiana nursing home in 1999, Paul Edge...
# 3  In futuristic London, Alex DeLarge is the lead...
# 4  On the day of his only daughter's wedding, Vit...

# %%
search_similar_movies('comedy and romance')
# Out:
#    Relevance   Movie Title                                         Movie Plot
# 0      64.66       Network  Howard Beale, the longtime anchor of the Union...
# 1      54.40   Raging Bull  In a brief scene in 1964, an aging, overweight...
# 2      52.74  Forrest Gump  While waiting at a bus stop in 1981, Forrest G...
# 3      -0.00    Goodfellas  Henry Hill (Liotta) admits, "As far back as I ...
# 4      -0.00         Giant  Jordan "Bick" Benedict (Rock Hudson), head of ...

# %%
search_similar_movies('history')
# Out:
#    Relevance         Movie Title  \
# 0      85.92              Gandhi
# 1      35.78               Rocky
# 2      29.20       The Apartment
# 3      22.37  The Maltese Falcon
# 4       0.00        12 Angry Men
#
#                                           Movie Plot
# 0  The screenplay of Gandhi is available as a pub...
# 1  On November 25, 1975, Rocky Balboa (Sylvester ...
# 2  Calvin Clifford (C. C.) "Bud" Baxter (Jack Lem...
# 3  \n\n\nIn 1539 the Knight Templars of Malta, pa...
# 4   The story begins in a New York City courthous...

# %%
search_similar_movies('horror')
# Out:
#    Relevance                       Movie Title  \
# 0      75.46                    Apocalypse Now
# 1      54.96                      The Exorcist
# 2      35.35                            Psycho
# 3       0.00       The Best Years of Our Lives
# 4      -0.00  The Treasure of the Sierra Madre
#
#                                           Movie Plot
# 0  In 1969, U.S. Army Captain and special operati...
# 1  Lankester Merrin is a veteran Catholic priest ...
# 2  Patrick Bateman is a wealthy investment banker...
# 3  After World War II, Fred Derry (Dana Andrews),...
# 4  Dobbs (Humphrey Bogart) and Curtin (Tim Holt),...

# %%
search_similar_movies('history and drama')
# Out:
#    Relevance         Movie Title  \
# 0      75.92               Rocky
# 1      59.85              Gandhi
# 2      20.34       The Apartment
# 3      15.58  The Maltese Falcon
# 4       0.00          Braveheart
#
#                                           Movie Plot
# 0  On November 25, 1975, Rocky Balboa (Sylvester ...
# 1  The screenplay of Gandhi is available as a pub...
# 2  Calvin Clifford (C. C.) "Bud" Baxter (Jack Lem...
# 3  \n\n\nIn 1539 the Knight Templars of Malta, pa...
# 4  In 1280, King Edward "Longshanks" (Patrick Mcg...

# %%
search_similar_movies('mystery and thriller')
# Out:
#    Relevance               Movie Title  \
# 0      67.52        The Maltese Falcon
# 1      54.48     2001: A Space Odyssey
# 2      40.06              Citizen Kane
# 3      30.67                    Psycho
# 4       0.00  The Shawshank Redemption
#
#                                           Movie Plot
# 0  \n\n\nIn 1539 the Knight Templars of Malta, pa...
# 1  The film consists of four major sections, all ...
# 2  \n\n\n\nOrson Welles as Charles Foster Kane\n\...
# 3  Patrick Bateman is a wealthy investment banker...
# 4  In 1947, banker Andy Dufresne is convicted of ...

# %%
search_similar_movies('crime and drama')
# Out:
#    Relevance         Movie Title  \
# 0      63.47               Rocky
# 1      59.01          Goodfellas
# 2      32.20   On the Waterfront
# 3      21.03      The Green Mile
# 4      19.73  A Clockwork Orange
#
#                                           Movie Plot
# 0  On November 25, 1975, Rocky Balboa (Sylvester ...
# 1  Henry Hill (Liotta) admits, "As far back as I ...
# 2  Mob-connected union boss Johnny Friendly (Lee ...
# 3  In a Louisiana nursing home in 1999, Paul Edge...
# 4  In futuristic London, Alex DeLarge is the lead...

# %%
search_similar_movies('comedy')
# Out:
#    Relevance                                        Movie Title  \
# 0      71.09                                        Raging Bull
# 1      68.92                                       Forrest Gump
# 2       0.00  Dr. Strangelove or: How I Learned to Stop Worr...
# 3       0.00                                     Doctor Zhivago
# 4       0.00                               Mutiny on the Bounty
#
#                                           Movie Plot
# 0  In a brief scene in 1964, an aging, overweight...
# 1  While waiting at a bus stop in 1981, Forrest G...
# 2  United States Air Force Brigadier General Jack...
# 3  The film takes place mostly against a backdrop...
# 4  In the year 1787, the Bounty sets sail from En...

# %%
search_similar_movies('musical')
# Out:
#    Relevance                         Movie Title  \
# 0      65.53                 Yankee Doodle Dandy
# 1      48.58                 Singin' in the Rain
# 2      38.28                       The Apartment
# 3      30.73                  The Sound of Music
# 4      29.73  Close Encounters of the Third Kind
#
#                                           Movie Plot
# 0   \n  In the early days of World War II, Cohan ...
# 1  Don Lockwood is a popular silent film star wit...
# 2  Calvin Clifford (C. C.) "Bud" Baxter (Jack Lem...
# 3  In 1938, while living as a young postulant at ...
# 4  In the Sonoran Desert, French scientist Claude...

# %%
search_similar_movies('war and history')
# Out:
#    Relevance                     Movie Title  \
# 0      76.48                          Gandhi
# 1      29.11                           Rocky
# 2      23.76                   The Apartment
# 3      22.00                Schindler's List
# 4      21.07  All Quiet on the Western Front
#
#                                           Movie Plot
# 0  The screenplay of Gandhi is available as a pub...
# 1  On November 25, 1975, Rocky Balboa (Sylvester ...
# 2  Calvin Clifford (C. C.) "Bud" Baxter (Jack Lem...
# 3  In 1939, the Germans move Polish Jews into the...
# 4  \n\n\n\n\nThis section's plot summary may be t...

# %%
search_similar_movies('pyschological horror')
# Out:
#    Relevance                       Movie Title  \
# 0      75.46                    Apocalypse Now
# 1      54.96                      The Exorcist
# 2      35.35                            Psycho
# 3       0.00       The Best Years of Our Lives
# 4      -0.00  The Treasure of the Sierra Madre
#
#                                           Movie Plot
# 0  In 1969, U.S. Army Captain and special operati...
# 1  Lankester Merrin is a veteran Catholic priest ...
# 2  Patrick Bateman is a wealthy investment banker...
# 3  After World War II, Fred Derry (Dana Andrews),...
# 4  Dobbs (Humphrey Bogart) and Curtin (Tim Holt),...
